# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahrozhassan123/Myproject/blob/main/Number_game_python_project(user).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import randint

print ("In this program you will enter a number between 1 - 500."
       "\nAfter the computer will try to guess your number!")

number = 0

while number < 1 or number >500:
    number = int(input("\n\nEnter a number for the computer to guess: "))
    if number > 500:
        print ("Number must be lower than or equal to 500!")
    if number < 1:
        print ("Number must be greater than or equal to 1!")

guess = randint(1, 500)

print ("The computer takes a guess...", guess)

while guess != number:
    if guess > number:
        guess -= 1
        guess = randint(1, guess)
    else:
        guess += 1
        guess = randint(guess, 500)
    print ("The computer takes a guess...", guess)

print ("The computer guessed", guess, "and it was correct!")
# Out:
# In this program you will enter a number between 1 - 500.
# After the computer will try to guess your number!
#
#
# Enter a number for the computer to guess: 400
# The computer takes a guess... 239
# The computer takes a guess... 251
# The computer takes a guess... 285
# The computer takes a guess... 439
# The computer takes a guess... 368
# The computer takes a guess... 374
# The computer takes a guess... 398
# The computer takes a guess... 494
# The computer takes a guess... 67
# The computer takes a guess... 482
# The computer takes a guess... 65
# The computer takes a guess... 94
# The computer takes a guess... 308
# The computer takes a guess... 486
# The computer takes a guess... 119
# The computer takes a guess... 500
# The computer takes a guess... 239
# The computer takes a guess... 245
# The computer takes a guess... 457
# The computer takes a guess... 226
# The computer takes a guess... 494
# The computer takes a guess... 451
# The computer takes a guess... 60
# ...
